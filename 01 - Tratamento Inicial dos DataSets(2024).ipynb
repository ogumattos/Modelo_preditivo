# %% [markdown]
# # Carga, limpeza e consolidação inicial dos dados obtidos do ProInfo.
#
# A origem dos dados para essa rotina são 3 relatórios do ProInfo:<br>
#
# **** Lista de Protocolos ****<br>
# Obtida em: Ferramentas >> Consultar Protocolos:<br>
#  - Planilhas com os Processos com Julgados.<br>
#
# **** Lista de Resoluções ****<br>
# Obtida em: Ferramentas >> Consultar Peças Processuais: <br>
#  - Planilhas com a relação dos Processos com Resoluções; e<br>
#  - Arquivo PDF com o conteúdo das resoluções.<br>
#
#  Foram consideradas apenas as Resoluções da 2ª Câmara em 2013<br>
#
# **** Relatório de Decisões do Período ****<br>
# Obtida em: Relatórios >> Decisões no Período<br>
#  - Planilhas com os resultados dos processos julgados<br>
#
#
# O relatório de decisões só possui informações a partir de 2013, portanto os demais relatórios serão filtrados a partir dessa data.<br>
#
#
#
# Produtos:<br>
# 01 - ProInfo - Lista Protocolos v1_0.xlsx<br>
# 01 - ProInfo - Lista de Resoluções v1_0.xlsx<br>
# 01 - ProInfo - Lista de Decisões v1_0.xlsx<br>
# 01 - ProInfo - Lista Consolidada v1_0.xlsx<br>

# %%
# %conda install -c anaconda xlrd
# %pip install xlrd
# %pip install --upgrade pip
# %pip install openpyxl
# %conda install tabulate
# %conda install -n base ipykernel --update-deps --force-reinstall

# %%
import pandas as pd
import os

if os.name == 'nt':  # Windows
    path_produtos = 'Dados\\Produtos\\'
    path_originais = 'Dados\\Coletados\\'
    path_ajustados = 'Dados\\Ajustados\\'
else:  # Ubuntu
    path_produtos = 'Dados/Produtos/'
    path_originais = 'Dados/Coletados/'
    path_ajustados = 'Dados/Ajustados/'

# %% [markdown]
# ## Compilação e limpeza do arquivo de Protocolos

# %%
# Gera DataSet geral com todos os protocolos do ProInfo gerados por Consultar Protocolo

def juntar(df, arq, header, last_col):
    df_temp = pd.read_excel(path_originais+arq, header=header, usecols=list(range(1,last_col)))
    df_temp.dropna(how='all', inplace=True)
    df = pd.concat([df,df_temp], ignore_index=True)
    return df

df_prot = pd.DataFrame()
df_prot = juntar(df_prot, 'PROInfo - Lista Protocolos (2013).xls', 2, 27)
df_prot = juntar(df_prot, 'PROInfo - Lista Protocolos(2014-2016).xls', 2, 27)
df_prot = juntar(df_prot, 'PROInfo - Lista Protocolos(2017-2024).xls', 2, 27)

df_prot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3809 entries, 0 to 3808
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Nº Protocolo                    3809 non-null   object
#  1   Tipo do Protocolo               3809 non-null   object
#  2   Situação                        3809 non-null   object
#  3   Natureza                        3809 non-null   object
#  4   Data do Protocolo               3809 non-null   datetime64[ns]
#  5   Volumes                         3809 non-null   float64
#  6   Prazo                           1867 non-null   datetime64[ns]
#  7   Sessão de Julgamento            3809 non-null   datetime64[ns]
#  8   Informações Complementares      1577 non-null   object
#  9   Anexos                          1498 non-null   object
#  10  Relator                         3809 non-null   object
#  11  Revisor                         3 non-null      object
#  12  Localização                     3809 non-null   object
#  13  Data de Entrada na Localização  3809 non-null   datetime64[ns]
#  14  Tempo de Permanência            3809 non-null   object
#  15  Data do Último Trâmite          3809 non-null   datetime64[ns]
#  16  Motivo do Último Trâmite        3809 non-null   object
#  17  Data do Último Recebimento      3796 non-null   datetime64[ns]
#  18  Última Guia                     3703 non-null   float64
#  19  Envolvido Pessoa Física         3805 non-null   object
#  20  Envolvido Pessoa Jurídica       3809 non-null   object
#  21  Nº de Origem                    3004 non-null   object
#  22  Exercício                       3764 non-null   object
#  23  Cadastro                        0 non-null      float64
#  24  Colegiado                       3808 non-null   object
#  25  Procuradoria                    1465 non-null   object
# dtypes: datetime64[ns](6), float64(3), object(17)
# memory usage: 773.8+ KB

# %%
df_prot['Sessão de Julgamento'].dt.year.value_counts().sort_index()
# Out:
# Sessão de Julgamento
# 2013    290
# 2014    924
# 2015    441
# 2016    262
# 2017    201
# 2018    241
# 2019    214
# 2020    199
# 2021    217
# 2022    342
# 2023    297
# 2024    181
# Name: count, dtype: int64

# %%
df_prot.describe(include=object)
# Out:
#            Nº Protocolo Tipo do Protocolo  \
# count              3809              3809
# unique             3809                 1
# top     TCE/012907/2023          Processo
# freq                  1              3809
#
#                                                  Situação  \
# count                                                3809
# unique                                                 58
# top     ARQUIVADO - JULGADO - CONFERIDO - NO ARQUIVO -...
# freq                                                 1257
#
#                                                  Natureza  \
# count                                                3809
# unique                                                 13
# top     COMPROVAÇÃO, PRESTAÇÃO E TOMADA DE CONTAS - RE...
# freq                                                 1697
#
#        Informações Complementares     Anexos                       Relator  \
# count                        1577       1498                          3809
# unique                       1559        557                            13
# top                RECONSTITUIÇÃO  VOLUME II  Pedro Henrique Lino de Souza
# freq                            6        246                          1170
#
#                          Revisor Localização Tempo de Permanência  \
# count                          3        3809                 3809
# unique                         3          53                  235
# top     MANOEL FIGUEIREDO CASTRO  No Arquivo               <1 min
# freq                           1        2533                 3315
#
#        Motivo do Último Trâmite          Envolvido Pessoa Física  \
# count                      3809                             3805
# unique                       13                             3552
# top                    Arquivar  Gestor: JOSÉ CARLOS LIMA SANTOS
# freq                       3307                               18
#
#                                 Envolvido Pessoa Jurídica  \
# count                                                3809
# unique                                               2854
# top     Órgão de Origem: SECRETARIA DA SAÚDE, Entidade...
# freq                                                   27
#
#                               Nº de Origem  Exercício  Colegiado  \
# count                                 3004     3764.0       3808
# unique                                2712       50.0          3
# top     Oficio nº 083 /2021 - CONDER/DIPRE     2010.0  2ª Câmara
# freq                                    23      213.0       3044
#
#                            Procuradoria
# count                              1465
# unique                                6
# top     (2PC) 2ª Procuradoria de Contas
# freq                                375

# %%
# Código para eliminar registros de Protocolos duplicados, mantendo os mais recentes.
# Não foram encontrados registros duplicados.

#df_prot = df_prot.sort_values('Sessão de Julgamento').drop_duplicates('Nº Protocolo', keep='last')
#print(df_prot.info())
#print(df_prot.describe(include=object).to_markdown())

# %%
df_prot.to_excel(path_ajustados+'01 - ProInfo - Lista Protocolos.xlsx')

# %% [markdown]
# ## Compilação e limpeza do arquivo de Resoluções

# %%
# Gera DataSet geral de todos as resoluções do ProInfo (Consultar Peças Processuais )

def JuntarResol(df, arq):
    df_temp = pd.read_excel(path_originais+arq, header=2, usecols=list(range(1,9)))
    df_temp.dropna(how='all', inplace=True)
    df = pd.concat([df,df_temp], ignore_index=True)
    return df

df_resol = pd.DataFrame()
df_resol = JuntarResol(df_resol, 'PROInfo - Lista de Peças Processuais(Resoluções 2014-2024).xls')
df_resol = JuntarResol(df_resol, 'PROInfo - Lista de Peças Processuais(Resoluções 1ª Câmara 2014-2024).xls')
df_resol = JuntarResol(df_resol, 'PROInfo - Lista de Peças Processuais(Resoluções 2ª Câmara 2013).xls')
df_resol = JuntarResol(df_resol, 'PROInfo - Lista de Peças Processuais(Resoluções 2ª Câmara 2014-2019).xls')
df_resol = JuntarResol(df_resol, 'PROInfo - Lista de Peças Processuais(Resoluções 2ª Câmara 2020-2024).xls')

print(df_resol.info())
print(df_resol.describe(include=object).to_markdown())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3531 entries, 0 to 3530
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ref.           3531 non-null   float64
#  1   Tipo           3531 non-null   object
#  2   Número/Ano     3531 non-null   object
#  3   Título         3531 non-null   object
#  4   Nº Protocolo   3531 non-null   object
#  5   Natureza       3531 non-null   object
#  6   Setor Criação  3529 non-null   object
#  7   Data Criação   3531 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 220.8+ KB
# None
# |        | Tipo                   | Número/Ano     | Título    | Nº Protocolo    | Natureza                                                                             | Setor Criação   |
# |:-------|:-----------------------|:---------------|:----------|:----------------|:-------------------------------------------------------------------------------------|:----------------|
# | count  | 3531                   | 3531           | 3531      | 3531            | 3531                                                                                 | 3529            |
# | unique | 3                      | 2877           | 2562      | 3424            | 12                                                                                   | 3               |
# | top    | Resolução da 2ª Câmara | Nº 000011/2017 | RESOLUÇÃO | TCE/001863/2006 | COMPROVAÇÃO, PRESTAÇÃO E TOMADA DE CONTAS-RECURSOS ESTADUAIS ATRIBUÍDOS A MUNICÍPIOS | 2ª Câmara       |
# | freq   | 2727                   | 21             | 776       | 3               | 1573                                                                                 | 2725            |

# %%
# Eliminação dos registros de Protocolos duplicados, mantendo os mais recentes.
df_resol = df_resol.sort_values('Data Criação').drop_duplicates('Nº Protocolo', keep='last')
print(df_resol.info())
print(df_resol.describe(include=object).to_markdown())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3424 entries, 868 to 3104
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ref.           3424 non-null   float64
#  1   Tipo           3424 non-null   object
#  2   Número/Ano     3424 non-null   object
#  3   Título         3424 non-null   object
#  4   Nº Protocolo   3424 non-null   object
#  5   Natureza       3424 non-null   object
#  6   Setor Criação  3422 non-null   object
#  7   Data Criação   3424 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 240.8+ KB
# None
# |        | Tipo                   | Número/Ano     | Título    | Nº Protocolo    | Natureza                                                                             | Setor Criação   |
# |:-------|:-----------------------|:---------------|:----------|:----------------|:-------------------------------------------------------------------------------------|:----------------|
# | count  | 3424                   | 3424           | 3424      | 3424            | 3424                                                                                 | 3422            |
# | unique | 3                      | 2813           | 2484      | 3424            | 12                                                                                   | 3               |
# | top    | Resolução da 2ª Câmara | Nº 000011/2017 | RESOLUÇÃO | TCE/008283/2020 | COMPROVAÇÃO, PRESTAÇÃO E TOMADA DE CONTAS-RECURSOS ESTADUAIS ATRIBUÍDOS A MUNICÍPIOS | 2ª Câmara       |
# | freq   | 2659                   | 21             | 753       | 1               | 1536                                                                                 | 2657            |

# %%
df_resol['Data Criação'].dt.year.value_counts().sort_index()
# Out:
# Data Criação
# 2013     66
# 2014    824
# 2015    395
# 2016    241
# 2017    201
# 2018    241
# 2019    195
# 2020    212
# 2021    224
# 2022    343
# 2023    299
# 2024    183
# Name: count, dtype: int64

# %%
df_resol.to_excel(path_ajustados+'01 - ProInfo - Lista de Resoluções.xlsx')

# %% [markdown]
# ## Compilação e limpeza do arquivo de Decisões

# %%
# Antes de executar a carga do arquivo foi realizado um ajuste manual diretamente no arquivo
# apagando as linhas de totalização e rodapé do relatório gerado pelo ProInfo.

def JuntarDecis(df, arq):
    df_temp = pd.read_excel(path_originais+arq, header=4, usecols=list(range(1,18)))
    df_temp.dropna(how='all', inplace=True)
    df = pd.concat([df,df_temp], ignore_index=True)
    return df

df_decis = pd.DataFrame()
df_decis = JuntarDecis(df_decis, 'PROInfo - Relatorio de decisoes no periodo(2013).xls')
df_decis = JuntarDecis(df_decis, 'PROInfo - Relatorio de decisoes no periodo(2014-2024).xls')
df_decis = df_decis[df_decis['Processo'].notnull()]
print(df_decis.info())
print(df_decis.describe(include=object).to_markdown())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3191 entries, 0 to 3191
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Colegiado           3191 non-null   object
#  1   Decisão             3191 non-null   object
#  2   Número              3191 non-null   float64
#  3   Ano                 3191 non-null   float64
#  4   Processo            3191 non-null   object
#  5   Natureza            3191 non-null   object
#  6   Ementa              3191 non-null   object
#  7   Tipo de julgamento  3191 non-null   object
#  8   Data da sessão      3191 non-null   datetime64[ns]
#  9   Relator             3191 non-null   object
#  10  Revisor             1 non-null      object
#  11  Data Protocolo      3191 non-null   datetime64[ns]
#  12  Envolvido PF        3174 non-null   object
#  13  Envolvido PJ        3191 non-null   object
#  14  Exercício           3150 non-null   object
#  15  Referenciados       55 non-null     object
#  16  Vinculados          209 non-null    object
# dtypes: datetime64[ns](2), float64(2), object(13)
# memory usage: 448.7+ KB
# None
# |        | Colegiado   | Decisão                | Processo        | Natureza                                                                               | Ementa                                                                                                                                                                                               | Tipo de julgamento                     | Relator                      | Revisor                        | Envolvido PF                 | Envolvido PJ        |   Exercício | Referenciados   | Vinculados      |
# |:-------|:------------|:-----------------------|:----------------|:---------------------------------------------------------------------------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------|:-----------------------------|:-------------------------------|:-----------------------------|:--------------------|------------:|:----------------|:----------------|
# | count  | 3191        | 3191                   | 3191            | 3191                                                                                   | 3191                                                                                                                                                                                                 | 3191                                   | 3191                         | 1                              | 3174                         | 3191                |        3150 | 55              | 209             |
# | unique | 3           | 4                      | 3165            | 9                                                                                      | 2873                                                                                                                                                                                                 | 59                                     | 13                           | 1                              | 1552                         | 143                 |          44 | 31              | 201             |
# | top    | 2ª Câmara   | Resolução da 2ª Câmara | TCE/001499/2012 | COMPROVAÇÃO, PRESTAÇÃO E TOMADA DE CONTAS - RECURSOS ESTADUAIS ATRIBUÍDOS A MUNICÍPIOS | RECURSOS ESTADUAIS ATRIBUÍDOS A MUNICÍPIOS. EXAME REALIZADO À LUZ DO DISPOSTO NO ITEM 5 DO ANEXO II DA RESOLUÇÃO REGIMENTAL Nº137/2013. ARQUIVAMENTO SEM BAIXA DE RESPONSABILIDADE. DECISÃO UNÂNIME. | Arquivar sem Baixa de Responsabilidade | Pedro Henrique Lino de Souza | Inaldo da Paixão Santos Araújo | WILSON JOSE VASCONCELOS DIAS | SECRETARIA DA SAÚDE |        2010 | TCE/011362/2019 | TCE/005211/2024 |
# | freq   | 2484        | 2490                   | 3               | 1511                                                                                   | 54                                                                                                                                                                                                   | 556                                    | 942                          | 1                              | 118                          | 414                 |         386 | 13              | 3               |

# %%
# Verifica se existem registros anteriores a 2014.
df_decis['Data da sessão'].dt.year.value_counts().sort_index()
# Out:
# Data da sessão
# 2013    100
# 2014    793
# 2015    394
# 2016    227
# 2017    158
# 2018    220
# 2019    199
# 2020    190
# 2021    216
# 2022    282
# 2023    251
# 2024    161
# Name: count, dtype: int64

# %%
# Verifica se existem arquivos com número de protocolo repetido.
df_decis[df_decis['Processo'].duplicated(keep=False)].sort_values(['Processo', 'Data da sessão']).head(6)
# Out:
#       Colegiado                 Decisão  Número     Ano         Processo  \
# 2177  2ª Câmara  Resolução da 2ª Câmara   234.0  2016.0  TCE/000081/2004
# 2511  2ª Câmara  Resolução da 2ª Câmara   191.0  2018.0  TCE/000081/2004
# 193   1ª Câmara  Resolução da 1ª Câmara    24.0  2019.0  TCE/000622/2007
# 659   1ª Câmara  Resolução da 1ª Câmara   108.0  2023.0  TCE/000622/2007
# 24    2ª Câmara  Resolução da 2ª Câmara   205.0  2013.0  TCE/001264/2010
# 2325  2ª Câmara  Resolução da 2ª Câmara   122.0  2017.0  TCE/001264/2010
#
#                                                Natureza  \
# 2177  COMPROVAÇÃO, PRESTAÇÃO E TOMADA DE CONTAS - RE...
# 2511  COMPROVAÇÃO, PRESTAÇÃO E TOMADA DE CONTAS - RE...
# 193   COMPROVAÇÃO, PRESTAÇÃO E TOMADA DE CONTAS - RE...
# 659   COMPROVAÇÃO, PRESTAÇÃO E TOMADA DE CONTAS - RE...
# 24    TOMADA DE CONTAS - TOMADA DE CONTAS DE PREFEIT...
# 2325  TOMADA DE CONTAS - TOMADA DE CONTAS DE PREFEIT...
#
#                                                  Ementa  \
# 2177  PRESTAÇÃO DE CONTAS DE RECURSOS ATRIBUÍDOS A E...
# 2511  CONVENIO. DESAPROVAÇÃO. DÉBITO. CÓPIA AO MPE. ...
# 193   PRESTAÇÃO DE CONTAS DE RECURSOS ESTADUAIS ATRI...
# 659   COMPROVAÇÃO, PRESTAÇÃO E TOMADA DE CONTAS - RE...
# 24    PRESTAÇÃO DE CONTAS DE RECURSOS ESTADUAIS ATRI...
# 2325  CONVENIO. NÃO APLICAR MULTA A SRA. EMÍLIA MARI...
#
#                  Tipo de julgamento Data da sessão  \
# 2177          Desaprovado em Débito     2016-10-26
# 2511          Desaprovado em Débito     2018-12-19
# 193    Desaprovado com Determinação     2019-03-19
# 659   Desaprovado com Recomendações     2023-06-06
# 24               Aprovado com Multa     2013-11-20
# 2325           Procedente sem multa     2017-08-23
#
#                            Relator Revisor Data Protocolo  \
# 2177  Pedro Henrique Lino de Souza     NaN     2004-01-08
# 2511  Pedro Henrique Lino de Souza     NaN     2004-01-08
# 193                 Carolina Matos     NaN     2007-02-13
# 659                 Carolina Matos     NaN     2007-02-13
# 24    Pedro Henrique Lino de Souza     NaN     2010-04-27
# 2325  Pedro Henrique Lino de Souza     NaN     2010-04-27
#
#                      Envolvido PF  \
# 2177          LUIZ GONZAGA MENDES
# 2511          LUIZ GONZAGA MENDES
# 193            MATEUS REIS SIMOES
# 659            MATEUS REIS SIMOES
# 24    EMILIA MARIA SALVADOR SILVA
# 2325  EMILIA MARIA SALVADOR SILVA
#
#                                            Envolvido PJ Exercício  \
# 2177  SECRETARIA DA AGRICULTURA, IRRIGAÇÃO E REFORMA...      2001
# 2511  SECRETARIA DA AGRICULTURA, IRRIGAÇÃO E REFORMA...      2001
# 193                                 SECRETARIA DA SAÚDE      2006
# 659                                 SECRETARIA DA SAÚDE      2006
# 24                          SECRETARIA DE TURISMO-SETUR    2009.0
# 2325                        SECRETARIA DE TURISMO-SETUR      2009
#
#      Referenciados Vinculados
# 2177           NaN        NaN
# 2511           NaN        NaN
# 193            NaN        NaN
# 659            NaN        NaN
# 24             NaN        NaN
# 2325           NaN        NaN

# %%
# Eliminação dos registros de Decisões duplicados, mantendo os mais recentes.
df_decis = df_decis.sort_values('Data da sessão').drop_duplicates('Processo', keep='last')
print(df_decis.info())
print(df_decis.describe(include=object).to_markdown())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3165 entries, 0 to 3188
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Colegiado           3165 non-null   object
#  1   Decisão             3165 non-null   object
#  2   Número              3165 non-null   float64
#  3   Ano                 3165 non-null   float64
#  4   Processo            3165 non-null   object
#  5   Natureza            3165 non-null   object
#  6   Ementa              3165 non-null   object
#  7   Tipo de julgamento  3165 non-null   object
#  8   Data da sessão      3165 non-null   datetime64[ns]
#  9   Relator             3165 non-null   object
#  10  Revisor             1 non-null      object
#  11  Data Protocolo      3165 non-null   datetime64[ns]
#  12  Envolvido PF        3148 non-null   object
#  13  Envolvido PJ        3165 non-null   object
#  14  Exercício           3125 non-null   object
#  15  Referenciados       52 non-null     object
#  16  Vinculados          201 non-null    object
# dtypes: datetime64[ns](2), float64(2), object(13)
# memory usage: 445.1+ KB
# None
# |        | Colegiado   | Decisão                | Processo        | Natureza                                                                               | Ementa                                                                                                                                                                                               | Tipo de julgamento                     | Relator                      | Revisor                        | Envolvido PF                 | Envolvido PJ        |   Exercício | Referenciados   | Vinculados      |
# |:-------|:------------|:-----------------------|:----------------|:---------------------------------------------------------------------------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------|:-----------------------------|:-------------------------------|:-----------------------------|:--------------------|------------:|:----------------|:----------------|
# | count  | 3165        | 3165                   | 3165            | 3165                                                                                   | 3165                                                                                                                                                                                                 | 3165                                   | 3165                         | 1                              | 3148                         | 3165                |        3125 | 52              | 201             |
# | unique | 3           | 3                      | 3165            | 9                                                                                      | 2850                                                                                                                                                                                                 | 58                                     | 13                           | 1                              | 1552                         | 143                 |          44 | 31              | 201             |
# | top    | 2ª Câmara   | Resolução da 2ª Câmara | TCE/008559/2021 | COMPROVAÇÃO, PRESTAÇÃO E TOMADA DE CONTAS - RECURSOS ESTADUAIS ATRIBUÍDOS A MUNICÍPIOS | RECURSOS ESTADUAIS ATRIBUÍDOS A MUNICÍPIOS. EXAME REALIZADO À LUZ DO DISPOSTO NO ITEM 5 DO ANEXO II DA RESOLUÇÃO REGIMENTAL Nº137/2013. ARQUIVAMENTO SEM BAIXA DE RESPONSABILIDADE. DECISÃO UNÂNIME. | Arquivar sem Baixa de Responsabilidade | Pedro Henrique Lino de Souza | Inaldo da Paixão Santos Araújo | WILSON JOSE VASCONCELOS DIAS | SECRETARIA DA SAÚDE |        2010 | TCE/011362/2019 | TCE/006523/2013 |
# | freq   | 2465        | 2469                   | 1               | 1502                                                                                   | 54                                                                                                                                                                                                   | 556                                    | 930                          | 1                              | 118                          | 411                 |         386 | 13              | 1               |

# %%
julgamentos = df_decis.loc[df_decis['Tipo de julgamento'].notna(),'Tipo de julgamento'].unique()
print(f'A quantidade de tipos de julgamento é de', len(julgamentos))
print('A quantidade de linhas duplicadas é de', len(df_decis[df_decis['Processo'].duplicated(keep=False)]))
# Out:
# A quantidade de tipos de julgamento é de 58
# A quantidade de linhas duplicadas é de 0

# %%
# Removendo da base os registros que não aprovam ou desaprovam os processos
julgamentos = df_decis.loc[df_decis['Tipo de julgamento'].notna(),'Tipo de julgamento'].unique()
apagar = [julgamento for julgamento in julgamentos if 'Aprovado' not in julgamento and 'Desaprovado' not in julgamento and 'Desaprovação' not in julgamento]
df_decis_removidas = df_decis[df_decis['Tipo de julgamento'].isin(apagar)]
df_decis = df_decis[~df_decis['Tipo de julgamento'].isin(apagar)]
print('Os tipos de julgamento apagados foram: ', apagar)
# O DataFrame de trabalho passa a ser df_decis[]
# Out:
# Os tipos de julgamento apagados foram:  ['Decisão Interna', 'Irregular', 'Arquivar', 'Arquivar sem Baixa de Responsabilidade', 'Devolver ao TCM', 'Conhecimento', 'Devolver ao TCU', 'Perda de Objeto', 'Procedente sem multa', 'Ilegalidade', 'Deu-se Provimento', 'Extinção do Processo', 'Expedir Determinação', 'Sobrestamento', 'Incompetência da corte', 'Juntar Prestação de Contas', 'Arquivamento e recomendação', 'Arquivar sem Baixa de Responsabilidade com Recomendações']

# %%
print(f'A quantidade de tipos de julgamento é de', len(df_decis['Tipo de julgamento'].unique()))
print('A quantidade de linhas duplicadas é de', len(df_decis[df_decis['Processo'].duplicated(keep=False)]))
# Out:
# A quantidade de tipos de julgamento é de 40
# A quantidade de linhas duplicadas é de 0

# %%
# Elimina decisões com Protocolos duplicados, mantendo os mais recentes.
df_decis = df_decis.sort_values('Data da sessão').drop_duplicates('Processo', keep='last')
print(f'A quantidade de tipos de julgamento é de', len(df_decis['Tipo de julgamento'].unique()))
print('A quantidade de linhas duplicadas é de', len(df_decis[df_decis['Processo'].duplicated(keep=False)]),'\n')
print(df_decis.info(),'\n')
print(df_decis.describe(include=object).to_markdown())
# Out:
# A quantidade de tipos de julgamento é de 40
# A quantidade de linhas duplicadas é de 0
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 2527 entries, 0 to 3188
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Colegiado           2527 non-null   object
#  1   Decisão             2527 non-null   object
#  2   Número              2527 non-null   float64
#  3   Ano                 2527 non-null   float64
#  4   Processo            2527 non-null   object
#  5   Natureza            2527 non-null   object
#  6   Ementa              2527 non-null   object
#  7   Tipo de julgamento  2527 non-null   object
#  8   Data da sessão      2527 non-null   datetime64[ns]
#  9   Relator             2527 non-null   object
#  10  Revisor             1 non-null      object
#  11  Data Protocolo      2527 non-null   datetime64[ns]
#  12  Envolvido PF        2511 non-null   object
#  13  Envolvido PJ        2527 non-null   object
#  14  Exercício           2497 non-null   object
#  15  Referenciados       38 non-null     object
#  16  Vinculados          194 non-null    object
# dtypes: datetime64[ns](2), float64(2), object(13)
# memory usage: 355.4+ KB
# None
#
# |        | Colegiado   | Decisão                | Processo        | Natureza                                                                               | Ementa                                                                                                                                                   | Tipo de julgamento   | Relator                      | Revisor                        | Envolvido PF                 | Envolvido PJ        |   Exercício | Referenciados   | Vinculados      |
# |:-------|:------------|:-----------------------|:----------------|:---------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------|:-----------------------------|:-------------------------------|:-----------------------------|:--------------------|------------:|:----------------|:----------------|
# | count  | 2527        | 2527                   | 2527            | 2527                                                                                   | 2527                                                                                                                                                     | 2527                 | 2527                         | 1                              | 2511                         | 2527                |        2497 | 38              | 194             |
# | unique | 2           | 2                      | 2527            | 9                                                                                      | 2367                                                                                                                                                     | 40                   | 13                           | 1                              | 1275                         | 120                 |          41 | 26              | 194             |
# | top    | 2ª Câmara   | Resolução da 2ª Câmara | TCE/008559/2021 | COMPROVAÇÃO, PRESTAÇÃO E TOMADA DE CONTAS - RECURSOS ESTADUAIS ATRIBUÍDOS A MUNICÍPIOS | RECURSOS ESTADUAIS ATRIBUÍDOS A MUNICÍPIOS. REGULAR APLICAÇÃO DOS RECURSOS TRANSFERIDOS. APROVAÇÃO DAS CONTAS. QUITAÇÃO AO RESPONSÁVEL. DECISÃO UNÂNIME. | Aprovado             | Pedro Henrique Lino de Souza | Inaldo da Paixão Santos Araújo | WILSON JOSE VASCONCELOS DIAS | SECRETARIA DA SAÚDE |        2010 | TCE/011362/2019 | TCE/006523/2013 |
# | freq   | 1887        | 1887                   | 1               | 1223                                                                                   | 23                                                                                                                                                       | 496                  | 744                          | 1                              | 114                          | 307                 |         301 | 5               | 1               |

# %%
df_decis.to_excel(path_ajustados+'01 - ProInfo - Lista de Decisões.xlsx')

# %% [markdown]
# # Conferência de compatibilidade do protocolos entre os arquivos
# Verifica se os protocolos listados em um arquivo aparecem nos outros

# %%
# Preparando variáveis com protocolos únicos existentes nos arquivos

set_decis = set(df_decis['Processo'])  # Aqui vou considerar todas as decisões antes da limpeza de dados.
set_resol = set(df_resol['Nº Protocolo'])
set_prot  = set(df_prot['Nº Protocolo'])
set_protocolos_comuns = set_decis & set_resol & set_prot
print(f"Qtde de Protocolos no arquivo de Decisões  = {len(set_decis)}, {len(df_decis)}")
print(f"Qtde de Protocolos no arquivo de Resoluções = {len(set_resol)}, {len(df_resol)}")
print(f"Qtde de Protocolos no arquivo de Protocolos = {len(set_prot)}, {len(df_prot)}")
print(f"Qtde de Protocolos que aparecem nos 3 arquivos = {len(set_protocolos_comuns)}, {len(set_protocolos_comuns)}")
# Out:
# Qtde de Protocolos no arquivo de Decisões  = 2527, 2527
# Qtde de Protocolos no arquivo de Resoluções = 3424, 3424
# Qtde de Protocolos no arquivo de Protocolos = 3809, 3809
# Qtde de Protocolos que aparecem nos 3 arquivos = 2525, 2525

# %%
# Análise dos protocolos em Decisões que não aparecem nos outros arquivos:
print(df_decis[df_decis['Processo'].isin(set_decis-set_protocolos_comuns)].to_markdown())
# Out:
# |      | Colegiado   | Decisão                |   Número |   Ano | Processo        | Natureza                                                                                   | Ementa                                                                                                                                                                                                                                      | Tipo de julgamento                    | Data da sessão      | Relator                            |   Revisor | Data Protocolo      | Envolvido PF                     | Envolvido PJ                                                     |   Exercício | Referenciados   |   Vinculados |
# |-----:|:------------|:-----------------------|---------:|------:|:----------------|:-------------------------------------------------------------------------------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:--------------------------------------|:--------------------|:-----------------------------------|----------:|:--------------------|:---------------------------------|:-----------------------------------------------------------------|------------:|:----------------|-------------:|
# | 1798 | 2ª Câmara   | Resolução da 2ª Câmara |      262 |  2015 | TCE/002882/2012 | COMPROVAÇÃO, PRESTAÇÃO E TOMADA DE CONTAS - RECURSOS ATRIBUÍDOS A ENTIDADES E INSTITUIÇÕES | PRESTAÇÃO DE CONTAS DE RECURSOS ESTADUAIS ATRIBUÍDOS A ENTIDADES E INSTITUIÇÕES. CONVÊNIO Nº 074/2011. RECURSOS APLICADOS. APROVAÇÃO COM RESSALVAS E DETERMINAÇÃO. ART. 24, I, DA LC Nº 005/91 C/C ART. 122, II, DO RITCE. DECISÃO UNÂNIME. | Aprovado com ressalva                 | 2015-07-01 00:00:00 | Marcus Vinícius de Barros Presídio |       nan | 2012-05-25 00:00:00 | JOSÉ TEODOMIRO TEIXEIRA GESTEIRA | SECRETARIA DA AGRICULTURA, IRRIGAÇÃO E REFORMA AGRÁRIA-SEAGRI    |        2011 | nan             |          nan |
# |  560 | 1ª Câmara   | Resolução da 1ª Câmara |      180 |  2022 | TCE/008649/2020 | COMPROVAÇÃO, PRESTAÇÃO E TOMADA DE CONTAS - RECURSOS ESTADUAIS ATRIBUÍDOS A MUNICÍPIOS     | Recursos Estaduais Atribuídos a Municípios. Desaprovação. Imputação de débito. Expedição de recomendações. Decisão por unanimidade.                                                                                                         | Desaprovado com Débito e Recomendação | 2022-10-04 00:00:00 | Inaldo da Paixão Santos Araújo     |       nan | 2020-12-09 00:00:00 | NÁDIA MÁRCIA CORREIA CAMPOS      | SECRETARIA DE JUSTIÇA, DIREITOS HUMANOS E DESENVOLVIMENTO SOCIAL |        2011 | TCE/005369/2021 |          nan |

# %%
# O processo TCE/002882/2012 está marcado como ARQUIVADO - RETIRADO DE SESSÃO DE JULGAMENTO - NOTIFICADO -
# O processo TCE/008649/2020 após recurso do interessado voltou a ficar em andamento.
# Ambos os processos serão descartados.
df_decis = df_decis[~df_decis['Processo'].isin(set(['TCE/002882/2012', 'TCE/008649/2020']))]

# %%
set_decis = set(df_decis['Processo']) 
set_resol = set(df_resol['Nº Protocolo'])
set_prot  = set(df_prot['Nº Protocolo'])
set_protocolos_comuns = set_decis & set_resol & set_prot
print(f"Qtde de Protocolos no arquivo de Decisões  = {len(set_decis)}, {len(df_decis)}")
print(f"Qtde de Protocolos no arquivo de Resoluções = {len(set_resol)}, {len(df_resol)}")
print(f"Qtde de Protocolos no arquivo de Protocolos = {len(set_prot)}, {len(df_prot)}")
print(f"Qtde de Protocolos que aparecem nos 3 arquivos = {len(set_protocolos_comuns)}, {len(set_protocolos_comuns)}")
# Out:
# Qtde de Protocolos no arquivo de Decisões  = 2525, 2525
# Qtde de Protocolos no arquivo de Resoluções = 3424, 3424
# Qtde de Protocolos no arquivo de Protocolos = 3809, 3809
# Qtde de Protocolos que aparecem nos 3 arquivos = 2525, 2525

# %%
# Todos os protocolos restantes das Decisões aparecem nos outros arquivos.

# %% [markdown]
# ## Análise dos protocolos que estão em Protocolos e Resoluções, mas não aparecem em decisões.

# %%
set_resol_proto = (set_resol | set_prot) - set_protocolos_comuns # Protocolos que aparecem em Protocolos e Resoluções e não aparece em Decisões
len(set_resol_proto)
# Out:
# 1293

# %%
# Verifica quantos protocolos foram removidos com base no texto da decisão (não foi aprovado nem desaprovado)
len(df_decis_removidas[df_decis_removidas['Processo'].isin(set_resol_proto)])
# Out:
# 638

# %%
set_resol_proto = set_resol_proto - set(df_decis_removidas['Processo']) # Retirados os protocolos removidos com base no texto da decisão (não foi aprovado nem desaprovado)
len(set_resol_proto)
# Out:
# 655

# %%
print(df_prot[df_prot['Nº Protocolo'].isin(set_resol_proto)][['Nº Protocolo','Informações Complementares']].to_markdown())
# Out:
# |      | Nº Protocolo    | Informações Complementares                                                                                                                                                                        |
# |-----:|:----------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |    1 | TCE/000655/2001 | nan                                                                                                                                                                                               |
# |    2 | TCE/000212/2002 | FUNDAÇÃO DE NEROLOGIA E NEUROCIRURGIA-INSTITUTO DO CEREBRO;Processo apensado ao processo TCE/000253/2002 em 28/04/03 11:53:42;Processo anexo ao processo TCE/000253/2002 em 20/03/2013 11:40:58   |
# |    3 | TCE/000215/2002 | Processo apensado ao processo TCE/000253/2002 em 28/3/2006 17:06:42;Processo anexo ao processo TCE/000253/2002 em 20/03/2013 11:40:58                                                             |
# |    4 | TCE/000253/2002 | FUNDAÇÃO DE NEUROLOGIA E NEUROCIRUGIA-INSTITUTO DO CEREBRO                                                                                                                                        |
# |    5 | TCE/000261/2002 | Processo apensado ao processo TCE/000253/2002 em 28/3/2006 17:07:03;Processo anexo ao processo TCE/000253/2002 em 20/03/2013 11:40:58                                                             |
# |    6 | TCE/000299/2002 | FUNDAÇÃO DE NEUROLOGIA E NEUROCIRURGIA-ISTITUTO DO CEREBRO;Processo apensado ao processo TCE/000253/2002 em 04/09/03 12:19:58;Processo anexo ao processo TCE/000253/2002 em 20/03/2013 11:40:58   |
# |    7 | TCE/001220/2002 | Processo apensado ao processo TCE/000558/2001 em 30/6/2005 16:32:46                                                                                                                               |
# |    8 | TCE/003501/2002 | Processo apensado ao processo TCE/000912/2003 em 9/2/2004 16:11:49                                                                                                                                |
# |   10 | TCE/006439/2002 | MARCIA TEREZA RANGEL OLIVEIRA;R$300.000;00.;Processo anexo ao processo TCE/003106/2013 em 15/07/2013 10:47:32                                                                                     |
# |   13 | TCE/010927/2002 | PREFEITURA DE ITAETÊ                                                                                                                                                                              |
# |   14 | TCE/011794/2002 | ASSOCIAÇÃO BAIANA DOS CRIADORES                                                                                                                                                                   |
# |   15 | TCE/013468/2002 | nan                                                                                                                                                                                               |
# |   16 | TCE/013902/2002 | Processo apensado ao processo TCE/000253/2002 em 3/9/2002 15:42:11;Processo anexo ao processo TCE/000253/2002 em 20/03/2013 11:40:58                                                              |
# |   17 | TCE/013903/2002 | Processo apensado ao processo TCE/000253/2002 em 3/9/2002 15:44:05;Processo anexo ao processo TCE/000253/2002 em 20/03/2013 11:40:58                                                              |
# |   18 | TCE/016806/2002 | FUNDAÇÃO DE NEUROLOGIA E NEUROCIRURGIA-INSTITUTO DO CÉREBRO;Processo apensado ao processo TCE/000253/2002 em 24/8/2006 15:01:58;Processo anexo ao processo TCE/000253/2002 em 20/03/2013 11:40:58 |
# |   23 | TCE/005292/2003 | nan                                                                                                                                                                                               |
# |   24 | TCE/005616/2003 | Processo anexo ao processo TCE/003624/2013 em 11/09/2013 11:33:55                                                                                                                                 |
# |   25 | TCE/006409/2003 | nan                                                                                                                                                                                               |
# |   27 | TCE/007687/2003 | Processo apensado ao processo TCE/000558/2001 em 30/6/2005 16:33:14                                                                                                                               |
# |   28 | TCE/008043/2003 | nan                                                                                                                                                                                               |
# |   29 | TCE/008059/2003 | nan                                                                                                                                                                                               |
# |   33 | TCE/000912/2004 | Processo apensado ao processo TCE/000446/2004 em 3/6/2004 16:40:57                                                                                                                                |
# |   34 | TCE/000913/2004 | Processo apensado ao processo TCE/000446/2004 em 3/6/2004 16:40:26                                                                                                                                |
# |   35 | TCE/000915/2004 | Processo apensado ao processo TCE/000446/2004 em 3/6/2004 16:39:51                                                                                                                                |
# |   36 | TCE/002532/2004 | nan                                                                                                                                                                                               |
# |   39 | TCE/003039/2004 | nan                                                                                                                                                                                               |
# |   40 | TCE/003143/2004 | Processo apensado ao processo TCE/000446/2004 em 21/12/2004 13:15:18                                                                                                                              |
# |   44 | TCE/005604/2004 | nan                                                                                                                                                                                               |
# |   45 | TCE/000111/2005 | nan                                                                                                                                                                                               |
# |   46 | TCE/000115/2005 | nan                                                                                                                                                                                               |
# |   47 | TCE/000668/2005 | nan                                                                                                                                                                                               |
# |   48 | TCE/000906/2005 | Processo apensado ao processo TCE/001792/2008 em 8/5/2008 17:49:09                                                                                                                                |
# |   49 | TCE/000908/2005 | Processo apensado ao processo TCE/001729/2008 em 20/5/2008 16:13:21                                                                                                                               |
# |   50 | TCE/001418/2005 | nan                                                                                                                                                                                               |
# |   51 | TCE/003189/2005 | Período de agosto a janeiro/2005                                                                                                                                                                  |
# |   52 | TCE/003773/2005 | nan                                                                                                                                                                                               |
# |   57 | TCE/005079/2005 | nan                                                                                                                                                                                               |
# |   58 | TCE/005227/2005 | Processo apensado ao processo TCE/002532/2004 em 1/12/2006 12:49:45;Processo anexo ao processo TCE/002532/2004 em 25/09/2013 11:43:01                                                             |
# |   59 | TCE/005284/2005 | Processo apensado ao processo TCE/002532/2004 em 1/12/2006 12:50:22;Processo anexo ao processo TCE/002532/2004 em 25/09/2013 11:43:01                                                             |
# |   60 | TCE/005300/2005 | Processo apensado ao processo TCE/002532/2004 em 1/12/2006 12:49:06;Processo anexo ao processo TCE/002532/2004 em 25/09/2013 11:43:01                                                             |
# |   61 | TCE/006349/2005 | nan                                                                                                                                                                                               |
# |   63 | TCE/007029/2005 | Processo apensado ao processo TCE/000668/2005 em 12/8/2008 19:45:12                                                                                                                               |
# |   66 | TCE/007264/2005 | nan                                                                                                                                                                                               |
# |   68 | TCE/007267/2005 | nan                                                                                                                                                                                               |
# |   69 | TCE/007454/2005 | Processo anexo ao processo TCE/003072/2013 em 09/07/2013 14:10:03                                                                                                                                 |
# |   70 | TCE/007832/2005 | nan                                                                                                                                                                                               |
# |   71 | TCE/007833/2005 | nan                                                                                                                                                                                               |
# |   72 | TCE/007873/2005 | Processo apensado ao processo TCE/005604/2004 em 17/3/2008 16:57:31;Processo anexo ao processo TCE/005604/2004 em 04/07/2013 09:18:57                                                             |
# |   73 | TCE/008386/2005 | nan                                                                                                                                                                                               |
# |   74 | TCE/000234/2006 | nan                                                                                                                                                                                               |
# |   75 | TCE/000591/2006 | nan                                                                                                                                                                                               |
# |   76 | TCE/000978/2006 | nan                                                                                                                                                                                               |
# |   77 | TCE/001322/2006 | nan                                                                                                                                                                                               |
# |   78 | TCE/001369/2006 | nan                                                                                                                                                                                               |
# |   80 | TCE/001832/2006 | Referente ao Período de Agosto/2005 a Fevereiro/2006.;Processo apensado ao processo TCE/007218/2005 em 14/8/2006 11:09:28                                                                         |
# |   81 | TCE/001864/2006 | nan                                                                                                                                                                                               |
# |   83 | TCE/002439/2006 | nan                                                                                                                                                                                               |
# |   84 | TCE/002649/2006 | nan                                                                                                                                                                                               |
# |   86 | TCE/002859/2006 | nan                                                                                                                                                                                               |
# |   87 | TCE/002988/2006 | nan                                                                                                                                                                                               |
# |   88 | TCE/003289/2006 | nan                                                                                                                                                                                               |
# |   89 | TCE/003770/2006 | nan                                                                                                                                                                                               |
# |   91 | TCE/004070/2006 | nan                                                                                                                                                                                               |
# |   92 | TCE/004073/2006 | nan                                                                                                                                                                                               |
# |   93 | TCE/004293/2006 | Processo apensado ao processo TCE/003039/2004 em 18/3/2010 19:52:28;Processo anexo ao processo TCE/003039/2004 em 31/07/2013 10:53:39                                                             |
# |   95 | TCE/004417/2006 | VIGÊNCIA EM 30/12/2002;Processo apensado ao processo TCE/008485/2003 em 21/8/2008 13:42:36                                                                                                        |
# |   96 | TCE/004583/2006 | Processo apensado ao processo TCE/001322/2006 em 15/4/2009 17:18:00;Processo anexo ao processo TCE/001322/2006 em 07/08/2013 10:35:41                                                             |
# |   98 | TCE/000069/2007 | nan                                                                                                                                                                                               |
# |   99 | TCE/000144/2007 | nan                                                                                                                                                                                               |
# |  100 | TCE/000717/2007 | Processo apensado ao processo TCE/006409/2003 em 27/3/2008 11:22:34;Processo anexo ao processo TCE/006409/2003 em 21/02/2013 11:42:28                                                             |
# |  101 | TCE/001097/2007 | nan                                                                                                                                                                                               |
# |  102 | TCE/001098/2007 | nan                                                                                                                                                                                               |
# |  103 | TCE/001130/2007 | nan                                                                                                                                                                                               |
# |  105 | TCE/002586/2007 | nan                                                                                                                                                                                               |
# |  108 | TCE/005029/2007 | nan                                                                                                                                                                                               |
# |  109 | TCE/005552/2007 | nan                                                                                                                                                                                               |
# |  110 | TCE/005872/2007 | nan                                                                                                                                                                                               |
# |  112 | TCE/005891/2007 | nan                                                                                                                                                                                               |
# |  113 | TCE/005967/2007 | nan                                                                                                                                                                                               |
# |  114 | TCE/005968/2007 | nan                                                                                                                                                                                               |
# |  115 | TCE/000766/2008 | CV 104/02.;Processo apensado ao processo TCE/002859/2006 em 19/11/2008 11:27:05;Processo anexo ao processo TCE/002859/2006 em 15/05/2013 10:23:37                                                 |
# |  116 | TCE/001124/2008 | nan                                                                                                                                                                                               |
# |  117 | TCE/001199/2008 | nan                                                                                                                                                                                               |
# |  118 | TCE/001232/2008 | nan                                                                                                                                                                                               |
# |  119 | TCE/001233/2008 | Processo apensado ao processo TCE/001232/2008 em 18/3/2008 15:38:47;Processo anexo ao processo TCE/001232/2008 em 17/04/2013 11:20:03                                                             |
# |  121 | TCE/001693/2008 | CV. 61/06;Processo apensado ao processo TCE/003999/2006 em 5/6/2008 16:55:00                                                                                                                      |
# |  123 | TCE/001730/2008 | nan                                                                                                                                                                                               |
# |  125 | TCE/001765/2008 | nan                                                                                                                                                                                               |
# |  127 | TCE/001953/2008 | nan                                                                                                                                                                                               |
# |  128 | TCE/002003/2008 | CV 01/03.;Processo apensado ao processo TCE/000111/2005 em 10/10/2008 10:20:14;Processo anexo ao processo TCE/000111/2005 em 24/04/2013 12:19:39                                                  |
# |  129 | TCE/002034/2008 | nan                                                                                                                                                                                               |
# |  130 | TCE/002035/2008 | nan                                                                                                                                                                                               |
# |  131 | TCE/002379/2008 | Processo apensado ao processo TCE/001729/2008 em 27/5/2008 18:04:28                                                                                                                               |
# |  133 | TCE/002482/2008 | nan                                                                                                                                                                                               |
# |  135 | TCE/002737/2008 | nan                                                                                                                                                                                               |
# |  136 | TCE/002739/2008 | nan                                                                                                                                                                                               |
# |  138 | TCE/002748/2008 | nan                                                                                                                                                                                               |
# |  142 | TCE/002872/2008 | Processo apensado ao processo TCE/002871/2008 em 1/7/2008 16:09:46                                                                                                                                |
# |  147 | TCE/002950/2008 | nan                                                                                                                                                                                               |
# |  149 | TCE/003057/2008 | nan                                                                                                                                                                                               |
# |  150 | TCE/003078/2008 | nan                                                                                                                                                                                               |
# |  152 | TCE/003140/2008 | nan                                                                                                                                                                                               |
# |  153 | TCE/003453/2008 | CV. Nº 129/06.                                                                                                                                                                                    |
# |  154 | TCE/003744/2008 | Processo apensado ao processo TCE/002871/2008 em 28/8/2008 10:15:17                                                                                                                               |
# |  158 | TCE/003759/2008 | nan                                                                                                                                                                                               |
# |  159 | TCE/003763/2008 | nan                                                                                                                                                                                               |
# |  160 | TCE/003990/2008 | nan                                                                                                                                                                                               |
# |  162 | TCE/004180/2008 | REF. CV. 114/00.                                                                                                                                                                                  |
# |  164 | TCE/004263/2008 | Processo anexo ao processo TCE/003926/2013 em 19/09/2013 14:50:04                                                                                                                                 |
# |  165 | TCE/004353/2008 | nan                                                                                                                                                                                               |
# |  166 | TCE/004507/2008 | nan                                                                                                                                                                                               |
# |  167 | TCE/004508/2008 | nan                                                                                                                                                                                               |
# |  168 | TCE/004620/2008 | nan                                                                                                                                                                                               |
# |  169 | TCE/004665/2008 | nan                                                                                                                                                                                               |
# |  171 | TCE/004995/2008 | nan                                                                                                                                                                                               |
# |  173 | TCE/000029/2009 | nan                                                                                                                                                                                               |
# |  174 | TCE/000119/2009 | nan                                                                                                                                                                                               |
# |  178 | TCE/000217/2009 | Processo apensado ao processo TCE/000591/2006 em 19/8/2010 14:01:06;Processo anexo ao processo TCE/000591/2006 em 25/09/2013 10:40:56                                                             |
# |  182 | TCE/000713/2009 | REF. CV. 05/06.                                                                                                                                                                                   |
# |  183 | TCE/000728/2009 | nan                                                                                                                                                                                               |
# |  184 | TCE/000802/2009 | nan                                                                                                                                                                                               |
# |  186 | TCE/001589/2009 | CV. 46/07.                                                                                                                                                                                        |
# |  187 | TCE/001841/2009 | nan                                                                                                                                                                                               |
# |  188 | TCE/001908/2009 | nan                                                                                                                                                                                               |
# |  189 | TCE/001913/2009 | Processo apensado ao processo TCE/000551/2011 em 23/07/2013 11:04:45;Processo anexo ao processo TCE/000551/2011 em 01/08/2013 08:50:09                                                            |
# |  191 | TCE/004313/2009 | nan                                                                                                                                                                                               |
# |  192 | TCE/004379/2009 | CV. 41/08                                                                                                                                                                                         |
# |  195 | TCE/005055/2009 | nan                                                                                                                                                                                               |
# |  196 | TCE/005076/2009 | Processo apensado ao processo TCE/000230/2009 em 5/11/2009 09:27:58                                                                                                                               |
# |  198 | TCE/005213/2009 | nan                                                                                                                                                                                               |
# |  199 | TCE/005445/2009 | CV. Nº 485/05.                                                                                                                                                                                    |
# |  202 | TCE/005711/2009 | nan                                                                                                                                                                                               |
# |  203 | TCE/000047/2010 | CV. Nº 31/08                                                                                                                                                                                      |
# |  204 | TCE/000050/2010 | nan                                                                                                                                                                                               |
# |  207 | TCE/000981/2010 | Processo apensado ao processo TCE/001841/2009 em 17/06/2013 15:50:09;Processo anexo ao processo TCE/001841/2009 em 04/07/2013 09:36:56                                                            |
# |  208 | TCE/001159/2010 | nan                                                                                                                                                                                               |
# |  210 | TCE/001332/2010 | CV. Nº 12/07.;Processo anexo ao processo TCE/003688/2013 em 11/09/2013 10:28:58                                                                                                                   |
# |  211 | TCE/001352/2010 | CV. Nº 53/01                                                                                                                                                                                      |
# |  212 | TCE/001358/2010 | nan                                                                                                                                                                                               |
# |  214 | TCE/001388/2010 | Processo anexo ao processo TCE/003211/2010 em 07/08/2013 15:34:41                                                                                                                                 |
# |  217 | TCE/001646/2010 | nan                                                                                                                                                                                               |
# |  218 | TCE/001647/2010 | nan                                                                                                                                                                                               |
# |  219 | TCE/001648/2010 | nan                                                                                                                                                                                               |
# |  221 | TCE/001686/2010 | nan                                                                                                                                                                                               |
# |  222 | TCE/001715/2010 | CVs. Nº 02 E 04/2007.                                                                                                                                                                             |
# |  225 | TCE/002722/2010 | nan                                                                                                                                                                                               |
# |  226 | TCE/003293/2010 | CV. Nº 282/2009.                                                                                                                                                                                  |
# |  227 | TCE/003763/2010 | nan                                                                                                                                                                                               |
# |  228 | TCE/003997/2010 | nan                                                                                                                                                                                               |
# |  230 | TCE/000427/2011 | CV. Nº 007/2008.                                                                                                                                                                                  |
# |  231 | TCE/000551/2011 | nan                                                                                                                                                                                               |
# |  232 | TCE/001027/2011 | CV. Nº 1206/2000.                                                                                                                                                                                 |
# |  233 | TCE/001104/2011 | CV. Nº 605/1999.                                                                                                                                                                                  |
# |  234 | TCE/001499/2011 | nan                                                                                                                                                                                               |
# |  235 | TCE/001529/2011 | nan                                                                                                                                                                                               |
# |  236 | TCE/001617/2011 | CONV. Nº 1257/2000.                                                                                                                                                                               |
# |  237 | TCE/001620/2011 | CONV. Nº 1083/2000.                                                                                                                                                                               |
# |  238 | TCE/001626/2011 | CONV. Nº 82/2002                                                                                                                                                                                  |
# |  239 | TCE/001629/2011 | CONV. Nº 1001/2003.                                                                                                                                                                               |
# |  240 | TCE/001655/2011 | nan                                                                                                                                                                                               |
# |  241 | TCE/001932/2011 | nan                                                                                                                                                                                               |
# |  243 | TCE/002237/2011 | nan                                                                                                                                                                                               |
# |  245 | TCE/002576/2011 | nan                                                                                                                                                                                               |
# |  246 | TCE/002657/2011 | CONV. Nº 013/2009.;Processo apensado ao processo TCE/005401/2011 em 25/04/2012 9:36:57;Processo anexo ao processo TCE/005401/2011 em 25/09/2013 11:26:59                                          |
# |  248 | TCE/003353/2011 | nan                                                                                                                                                                                               |
# |  249 | TCE/004868/2011 | nan                                                                                                                                                                                               |
# |  250 | TCE/005359/2011 | nan                                                                                                                                                                                               |
# |  251 | TCE/005390/2011 | nan                                                                                                                                                                                               |
# |  252 | TCE/005401/2011 | nan                                                                                                                                                                                               |
# |  253 | TCE/006014/2011 | Processo apensado ao processo TCE/003990/2008 em 27/10/2011 14:31:05;Processo anexo ao processo TCE/003990/2008 em 11/04/2013 12:12:05                                                            |
# |  254 | TCE/007622/2011 | nan                                                                                                                                                                                               |
# |  258 | TCE/000960/2012 | nan                                                                                                                                                                                               |
# |  259 | TCE/001042/2012 | nan                                                                                                                                                                                               |
# |  260 | TCE/001864/2012 | nan                                                                                                                                                                                               |
# |  261 | TCE/002140/2012 | nan                                                                                                                                                                                               |
# |  263 | TCE/003486/2012 | nan                                                                                                                                                                                               |
# |  264 | TCE/003487/2012 | nan                                                                                                                                                                                               |
# |  265 | TCE/003567/2012 | nan                                                                                                                                                                                               |
# |  266 | TCE/003674/2012 | nan                                                                                                                                                                                               |
# |  268 | TCE/003677/2012 | nan                                                                                                                                                                                               |
# |  269 | TCE/003698/2012 | nan                                                                                                                                                                                               |
# |  270 | TCE/004110/2012 | nan                                                                                                                                                                                               |
# |  271 | TCE/004139/2012 | nan                                                                                                                                                                                               |
# |  273 | TCE/004292/2012 | nan                                                                                                                                                                                               |
# |  275 | TCE/004794/2012 | nan                                                                                                                                                                                               |
# |  276 | TCE/005014/2012 | nan                                                                                                                                                                                               |
# |  277 | TCE/005015/2012 | nan                                                                                                                                                                                               |
# |  278 | TCE/005143/2012 | nan                                                                                                                                                                                               |
# |  279 | TCE/005309/2012 | nan                                                                                                                                                                                               |
# |  286 | TCE/000856/2013 | nan                                                                                                                                                                                               |
# |  287 | TCE/001205/2013 | nan                                                                                                                                                                                               |
# |  288 | TCE/001528/2013 | nan                                                                                                                                                                                               |
# |  289 | TCE/001981/2013 | nan                                                                                                                                                                                               |
# |  291 | TCE/001498/2007 | Processo apensado ao processo TCE/000109/2007 em 12/28/aaaa 10:15:03                                                                                                                              |
# |  312 | TCE/005302/2005 | Processo apensado ao processo TCE/005164/2005 em 20/9/2006 14:43:08                                                                                                                               |
# |  313 | TCE/007078/2005 | Processo apensado ao processo TCE/005164/2005 em 12/9/2006 16:47:00                                                                                                                               |
# |  314 | TCE/000228/2006 | Processo apensado ao processo TCE/005164/2005 em 12/9/2006 16:47:29                                                                                                                               |
# |  315 | TCE/003191/2006 | Processo apensado ao processo TCE/002196/2004 em 5/10/2006 09:35:30                                                                                                                               |
# |  316 | TCE/002093/2009 | Processo apensado ao processo TCE/001316/2009 em 10/04/2012 16:49:48                                                                                                                              |
# |  317 | TCE/000671/2010 | Processo apensado ao processo TCE/000991/2006 em 24/3/2010 11:19:03                                                                                                                               |
# |  371 | TCE/008213/2005 | Processo apensado ao processo TCE/004424/2005 em 14/6/2010 21:22:40                                                                                                                               |
# |  372 | TCE/003670/2006 | Processo apensado ao processo TCE/007018/2005 em 1/7/2010 14:54:32                                                                                                                                |
# |  373 | TCE/005888/2007 | Processo apensado ao processo TCE/005890/2007 em 22/8/2008 10:43:42                                                                                                                               |
# |  374 | TCE/000583/2008 | Processo apensado ao processo TCE/007018/2005 em 1/7/2010 14:54:49                                                                                                                                |
# |  375 | TCE/001003/2008 | Processo apensado ao processo TCE/001002/2008 em 6/3/2008 20:26:20                                                                                                                                |
# |  376 | TCE/001745/2008 | Processo apensado ao processo TCE/004424/2005 em 14/6/2010 21:23:29                                                                                                                               |
# |  377 | TCE/002954/2008 | Processo apensado ao processo TCE/004424/2005 em 14/6/2010 21:23:04                                                                                                                               |
# |  378 | TCE/003079/2008 | Processo apensado ao processo TCE/001002/2008 em 24/4/2012 15:54:42                                                                                                                               |
# |  379 | TCE/004566/2009 | Processo apensado ao processo TCE/003987/2008 em 19/3/2010 12:39:23                                                                                                                               |
# |  417 | TCE/006315/2005 | Processo apensado ao processo TCE/002813/2006 em 18/10/2010 10:31:36                                                                                                                              |
# |  418 | TCE/003283/2006 | Processo apensado ao processo TCE/002813/2006 em 18/10/2010 10:32:09                                                                                                                              |
# |  419 | TCE/005056/2008 | Processo apensado ao processo TCE/003493/2008 em 12/12/2008 11:52:26                                                                                                                              |
# |  420 | TCE/001521/2010 | Processo apensado ao processo TCE/002813/2006 em 18/10/2010 10:33:27                                                                                                                              |
# ...
# | 3368 | TCE/008320/2020 | FIPLAN Nº 3010100011900000942/2019                                                                                                                                                                |
# | 3369 | TCE/008326/2020 | Número FIPLAN do Convênio: 2210100011900000747/2019                                                                                                                                               |
# | 3370 | TCE/008332/2020 | FIPLAN Nº 2210100011900000984/2019                                                                                                                                                                |
# | 3371 | TCE/008333/2020 | nan                                                                                                                                                                                               |
# | 3372 | TCE/008334/2020 | FIPLAN Nº 2210100011900000763/2019                                                                                                                                                                |
# | 3373 | TCE/008335/2020 | FIPLAN Nº  2210100011900000771/2019.                                                                                                                                                              |
# | 3387 | TCE/008777/2020 | REF: Tomada de Contas Especial - Recursos estaduais atribuídos a municípios.                                                                                                                      |
# |      |                 | Convênio 060/2014 - Santa Cruz da Vitória                                                                                                                                                         |
# |      |                 | OBS: Anexos digitalizados pela parte e inseridos na composição através de CD-R.                                                                                                                   |
# | 3416 | TCE/000771/2021 | nan                                                                                                                                                                                               |
# | 3417 | TCE/000774/2021 | nan                                                                                                                                                                                               |
# | 3430 | TCE/001319/2021 | nan                                                                                                                                                                                               |
# | 3432 | TCE/001548/2021 | nan                                                                                                                                                                                               |
# | 3502 | TCE/006298/2021 | nan                                                                                                                                                                                               |
# | 3504 | TCE/006301/2021 | nan                                                                                                                                                                                               |
# | 3508 | TCE/006310/2021 | nan                                                                                                                                                                                               |
# | 3512 | TCE/006315/2021 | nan                                                                                                                                                                                               |
# | 3513 | TCE/006317/2021 | nan                                                                                                                                                                                               |
# | 3514 | TCE/006324/2021 | nan                                                                                                                                                                                               |
# | 3515 | TCE/006326/2021 | nan                                                                                                                                                                                               |
# | 3516 | TCE/006328/2021 | nan                                                                                                                                                                                               |
# | 3517 | TCE/006329/2021 | nan                                                                                                                                                                                               |
# | 3518 | TCE/006330/2021 | nan                                                                                                                                                                                               |
# | 3519 | TCE/006331/2021 | nan                                                                                                                                                                                               |
# | 3523 | TCE/006339/2021 | nan                                                                                                                                                                                               |
# | 3550 | TCE/007859/2021 | Email: gabriela.santos@sudesb.ba.gov.br Data/Hora: 20/10/2021 16:43                                                                                                                               |
# |      |                 | Termo de Colaboração nº 12/2017                                                                                                                                                                   |
# | 3551 | TCE/007881/2021 | Email: gabriela.santos@sudesb.ba.gov.br Data/Hora: Qui, 21/10/2021 13:22                                                                                                                          |
# | 3552 | TCE/007885/2021 | Email: gabriela.santos@sudesb.ba.gov.br Data/Hora: Qui, 21/10/2021 14:22                                                                                                                          |
# |      |                 | Termo de Colaboração 08/2017                                                                                                                                                                      |
# | 3553 | TCE/007931/2021 | REF: : PROCESSO DE REPARAÇÃO DE DANOS - RESSARCIMENTO - MCPS TERMO DE                                                                                                                             |
# |      |                 | COLABORAÇÃO 07-2017.                                                                                                                                                                              |
# |      |                 | Email.: gabriela.santos@sudesb.ba.gov.br  Data e horário do recebimento: 25/10/2021 10:33                                                                                                         |
# | 3578 | TCE/008157/2021 | nan                                                                                                                                                                                               |
# | 3585 | TCE/008456/2021 | nan                                                                                                                                                                                               |
# | 3586 | TCE/008465/2021 | nan                                                                                                                                                                                               |
# | 3603 | TCE/008600/2021 | Email.: daniela.borges@cultura.ba.gov.br  Data e horário do recebimento: 16/11/2021 15:06                                                                                                         |
# |      |                 | REF: Isso não é um Close: Residências Pandeo 2019 - TAC nº 25/2019 - Levi Santos Barbosa                                                                                                          |
# | 3616 | TCE/009151/2021 | nan                                                                                                                                                                                               |
# | 3617 | TCE/009152/2021 | nan                                                                                                                                                                                               |
# | 3618 | TCE/009153/2021 | nan                                                                                                                                                                                               |
# | 3619 | TCE/009196/2021 | nan                                                                                                                                                                                               |
# | 3620 | TCE/009197/2021 | nan                                                                                                                                                                                               |
# | 3625 | TCE/009496/2021 | nan                                                                                                                                                                                               |
# | 3628 | TCE/009638/2021 | Email: graziele.silva@fapesb.ba.gov.br Data/Hora: Seg, 13/12/2021 10:13                                                                                                                           |
# | 3632 | TCE/009649/2021 | nan                                                                                                                                                                                               |
# | 3636 | TCE/009665/2021 | nan                                                                                                                                                                                               |
# | 3651 | TCE/009820/2021 | nan                                                                                                                                                                                               |
# | 3653 | TCE/009930/2021 | nan                                                                                                                                                                                               |
# | 3654 | TCE/009950/2021 | nan                                                                                                                                                                                               |
# | 3656 | TCE/009959/2021 | nan                                                                                                                                                                                               |
# | 3657 | TCE/009961/2021 | nan                                                                                                                                                                                               |
# | 3658 | TCE/009962/2021 | nan                                                                                                                                                                                               |
# | 3663 | TCE/000119/2022 | Email.: graziele.silva@fapesb.ba.gov.br  Data e horário do recebimento: 10/01/2022 11:53                                                                                                          |
# |      |                 | REF: Tomada de Contas - RED0001/2013.                                                                                                                                                             |
# | 3682 | TCE/001872/2022 | ANEXOS DIGITALIZADOS PELA PARTE, VIA CD-ROM.                                                                                                                                                      |
# |      |                 | TERMO DE COLABORAÇÃO Nº 014/2019 (PROCESSO SEI 004.3050.2021.0000354-13)                                                                                                                          |
# | 3713 | TCE/006346/2022 | nan                                                                                                                                                                                               |
# | 3714 | TCE/006348/2022 | nan                                                                                                                                                                                               |
# | 3726 | TCE/007335/2022 | nan                                                                                                                                                                                               |
# | 3727 | TCE/007349/2022 | nan                                                                                                                                                                                               |
# | 3739 | TCE/007776/2022 | nan                                                                                                                                                                                               |
# | 3741 | TCE/008551/2022 | nan                                                                                                                                                                                               |
# | 3764 | TCE/004777/2023 | nan                                                                                                                                                                                               |
# | 3773 | TCE/009128/2023 | nan                                                                                                                                                                                               |
# | 3788 | TCE/010984/2023 | nan                                                                                                                                                                                               |
# | 3789 | TCE/010985/2023 | nan                                                                                                                                                                                               |
# | 3792 | TCE/011097/2023 | nan                                                                                                                                                                                               |
# | 3794 | TCE/011121/2023 | nan                                                                                                                                                                                               |
# | 3795 | TCE/011324/2023 | nan                                                                                                                                                                                               |
# | 3807 | TCE/012779/2023 | nan                                                                                                                                                                                               |

# %% [markdown]
# Os casos avaliados em uma amostra selecionada identificou apenas situações em que o protocolo havia sido apensado a outro processo.
# Todos os casos serão descartados.
#
# Registro do funcionamento do ProInfo.<br>
#
# Vinculação são os processos e documentos associados aos arquivo em questão.<br>
# Referencia acontece quando um processo foi associado a outro <br>
#
# Considerando que o Processo A foi apensado ao processo B e este ao processo C então:
#
# Situação do Processo A:
# - Vinculados: nenhum
# - Referenciados: Processo B
#
# Situação do Processo B:
# - Vinculados: Processo A
# - Referenciados: Processo C
#
# Situação do Processo C:
# - Vinculados: Processo B e Processo A
# - Referenciados: nenhum

# %%
# Descarta todos os protocolos descasados do arquivo de decisões.
df_prot = df_prot[df_prot['Nº Protocolo'].isin(set_protocolos_comuns)]
df_resol = df_resol[df_resol['Nº Protocolo'].isin(set_protocolos_comuns)]
df_decis = df_decis[df_decis['Processo'].isin(set_protocolos_comuns)]

# %%
set_decis = set(df_decis['Processo']) 
set_resol = set(df_resol['Nº Protocolo'])
set_prot  = set(df_prot['Nº Protocolo'])
set_protocolos_comuns = set_decis & set_resol & set_prot
print(f"Qtde de Protocolos no arquivo de Decisões  = {len(set_decis)}, {len(df_decis)}")
print(f"Qtde de Protocolos no arquivo de Resoluções = {len(set_resol)}, {len(df_resol)}")
print(f"Qtde de Protocolos no arquivo de Protocolos = {len(set_prot)}, {len(df_prot)}")
print(f"Qtde de Protocolos que aparecem nos 3 arquivos = {len(set_protocolos_comuns)}, {len(set_protocolos_comuns)}")
# Out:
# Qtde de Protocolos no arquivo de Decisões  = 2525, 2525
# Qtde de Protocolos no arquivo de Resoluções = 2525, 2525
# Qtde de Protocolos no arquivo de Protocolos = 2525, 2525
# Qtde de Protocolos que aparecem nos 3 arquivos = 2525, 2525

# %%
df_prot.to_excel(path_produtos+'01 - ProInfo - Lista Protocolos v1_0.xlsx')
df_resol.to_excel(path_produtos+'01 - ProInfo - Lista de Resoluções v1_0.xlsx')
df_decis.to_excel(path_produtos+'01 - ProInfo - Lista de Decisões v1_0.xlsx')

# %% [markdown]
# # Gera um arquivo unificado com os atributos de interesse.

# %%
#path_produtos = 'Dados\Produtos\\'
df_prot = pd.read_excel(path_produtos+'01 - ProInfo - Lista Protocolos v1_0.xlsx', index_col=0)
df_resol = pd.read_excel(path_produtos+'01 - ProInfo - Lista de Resoluções v1_0.xlsx', index_col=0)
df_decis = pd.read_excel(path_produtos+'01 - ProInfo - Lista de Decisões v1_0.xlsx', index_col=0)

# %%
# Cria arquivo df_proinfo com as informações do ProInfo sobre os processos.
df_decis = df_decis[['Colegiado', 'Número', 'Ano', 'Processo',
                    'Natureza', 'Tipo de julgamento', 'Data da sessão',
                    'Relator', 'Exercício']]
df_decis.rename(columns={'Processo': 'Protocolo'}, inplace=True)
df_prot.rename(columns={'Nº Protocolo': 'Protocolo'}, inplace=True)
df_proinfo = df_decis.merge(df_prot[['Protocolo','Situação', 'Envolvido Pessoa Física', 'Envolvido Pessoa Jurídica', 'Nº de Origem']], 
               how='left', on='Protocolo')

df_proinfo.to_excel(path_produtos+'01 - ProInfo - Lista Consolidada v1_0.xlsx')

# %%
# Arquivo testado em 05/03/2025. Com alterações na WEB. Alterado. Mais ou menos teste
